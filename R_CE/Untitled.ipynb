# %%
# Out:
# usage: ipykernel_launcher.py [-h] [--alpha ALPHA]
# ipykernel_launcher.py: error: unrecognized arguments: -f /storage/wjwang/.local/share/jupyter/runtime/kernel-845708df-8ce1-4c5e-91e3-92cd41a86822.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
